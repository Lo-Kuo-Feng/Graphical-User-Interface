# %%
import tkinter as tk
from tkinter import messagebox

def openfile():
    try:
        with open('test.txt', 'r') as f:
            text1.insert('end', f.read())
    except:
        messagebox.showerror("Error","找不到檔案！")

def calculation():
    try:
        pass
    except:
        messagebox.showerror("Error","錯誤！")

def clear():
    text1.delete(0.0, "end")
    text2.delete(0.0, "end")
    text3.delete(0.0, "end")
    text1.insert('end', 'Start\n')
    text2.insert('end', 'Start\n')
    text3.insert('end', 'Start\n')

def about():
    messagebox.showinfo("Information","輸入矩陣數值,按下'計算'即可求矩陣行列式\n按下清除則會清空矩陣數值！")

window = tk.Tk()
window.iconbitmap('logo.ico')
window.title('Image processing')
window.geometry('860x680')

#=========================================================================================
menubar = tk.Menu(window)

filemenu = tk.Menu(menubar, tearoff=0)
menubar.add_cascade(label='File', menu=filemenu)
filemenu.add_command(label='Open', command=openfile)
filemenu.add_separator()
filemenu.add_command(label='Exit', command=window.destroy)


editmenu = tk.Menu(menubar, tearoff=0)
menubar.add_cascade(label='Edit', menu=editmenu)
editmenu.add_command(label='calculation', command=calculation)
editmenu.add_command(label='clear', command=clear) 

helpmenu = tk.Menu(menubar, tearoff=0)
menubar.add_cascade(label='Help', menu=helpmenu)
helpmenu.add_command(label='about', command=about) 

window.config(menu=menubar)
#==========================================================================================
frame1 = tk.Frame(window)
frame1.place(relx=0, rely=0, relheight=1, relwidth=0.5, anchor="nw" )
frame2 = tk.Frame(window)
frame2.place(relx=0.5, rely=0, relheight=0.5, relwidth=0.5, anchor="nw")
frame3 = tk.Frame(window)
frame3.place(relx=0.5, rely=0.5, relheight=0.5, relwidth=0.5, anchor="nw")
frame4 = tk.Frame(window)
frame4.place(relx=0, rely=0, height=50, relwidth=1, anchor="nw")
frame5 = tk.Frame(window)
frame5.place(relx=0, rely=1, height=30, relwidth=1, anchor="sw")




#====================================================================================================
b1 = tk.Button(frame4, text="c", command=calculation)
b1.config(width=8, height=50)
b1.grid(column=0, row=0)

b2 = tk.Button(frame4, text="c", command=calculation)
b2.config(width=8, height=50)
b2.grid(column=1, row=0)


#=================================================================================================================
sbar1 = tk.Scrollbar(frame1, orient="vertical")
text1 = tk.Text(frame1, wrap='word', background="white", foreground="black", font=("System",10))
text1.insert('end', 'Start\n')
sbar1.pack(side='right', fill='both',expand=False)
text1.pack(side='left', fill='both',expand=True)
sbar1["command"] = text1.yview
text1["yscrollcommand"] = sbar1.set


sbar2 = tk.Scrollbar(frame2, orient='horizontal')
text2 = tk.Text(frame2, wrap='none', background="#FFE873", foreground="#306998", font=('Comic Sans MS',10))
text2.insert('end', 'Start\n')
sbar2.pack(side='bottom', fill='both',expand=False)
text2.pack(side='left', fill='both',expand=True)
sbar2["command"] =text2.xview
text2["xscrollcommand"] =sbar2.set


sbar3 = tk.Scrollbar(frame3)
text3 = tk.Text(frame3, wrap='word', background="#4B8BBE", foreground="#306998", font=("System",10))
text3.insert('end', 'Start\n')
sbar3.pack(side='right', fill='both',expand=False)
text3.pack(side='left', fill='both',expand=True)
sbar3["command"] = text3.yview
text3["yscrollcommand"] = sbar3.set

#=======================================================================================
window.mainloop()

# %%
import tkinter as tk
import tkinter.filedialog as fd
from tkinter import messagebox
import PIL.Image
import PIL.ImageTk

#函數==============================================================
def openfile():
    try:
        global currentfile
        file_path = fd.askopenfilename()
        currentfile = file_path
        if file_path:
            with open(file_path, 'r') as f:
                text1.insert('end', f.read())
        else:
            pass
    except:
        messagebox.showerror("Error","檔案錯誤！")
        
def openphoto():
    file_path = fd.askopenfilename()
#     newImage = PIL.Image.open(path).convert("L").resize((32,32)).resize((300,300))
    newImage = PIL.Image.open(file_path)
    imageData = PIL.ImageTk.PhotoImage(newImage)
    label.configure(image=imageData)
    label.image = imageData
        
def save():
    try:
        if currentfile:
            with open(currentfile, 'w') as f:
                f.write('789')
        else:
            file_path = fd.asksaveasfilename(defaultextension="txt", initialfile="Untitled")
            if file_path:
                with open(file_path, 'w') as f:
                    f.write('789')
            else:
                pass
    except:
        messagebox.showerror("Error","檔案錯誤！")     
        
def saveas():
    try:
        file_path = fd.asksaveasfilename(defaultextension="txt", initialfile="Untitled")
        if file_path:
            with open(file_path, 'w') as f:
                f.write('789')
        else:
            pass
    except:
        messagebox.showerror("Error","檔案錯誤！")

def calculation():
    try:
        pass
    except:
        messagebox.showerror("Error","錯誤！")

def clear():
    text1.delete(0.0, "end")
#     text2.delete(0.0, "end")
    text3.delete(0.0, "end")
    text1.insert('end', 'Start\n')
#     text2.insert('end', 'Start\n')
    text3.insert('end', 'Start\n')
    
def clearphoto():
    label.config(image="")

def about():
    messagebox.showinfo("Information","輸入矩陣數值,按下'計算'即可求矩陣行列式\n按下清除則會清空矩陣數值！")
    
    
currentfile = None
    
window = tk.Tk()
window.iconbitmap('logo.ico')
window.title('Image processing')
window.geometry('1920x1080')

#菜單=========================================================================================
menubar = tk.Menu(window)

filemenu = tk.Menu(menubar, tearoff=0)
menubar.add_cascade(label='File', menu=filemenu)
filemenu.add_command(label='Open', command=openfile)
filemenu.add_command(label='Openphoto', command=openphoto)
filemenu.add_command(label='Save', command=save)
filemenu.add_command(label='Save as', command=saveas)
filemenu.add_separator()
filemenu.add_command(label='Exit', command=window.destroy)

editmenu = tk.Menu(menubar, tearoff=0)
menubar.add_cascade(label='Edit', menu=editmenu)
editmenu.add_command(label='calculation', command=calculation)
editmenu.add_command(label='clear', command=clear) 
editmenu.add_command(label='clearphoto', command=clearphoto) 

helpmenu = tk.Menu(menubar, tearoff=0)
menubar.add_cascade(label='Help', menu=helpmenu)
helpmenu.add_command(label='about', command=about) 

window.config(menu=menubar)
#布局==========================================================================================
frame1 = tk.Frame(window)
frame1.pack(side="top", fill="x", expand=False)

frame2 = tk.Frame(window)
frame2.pack(side="top", fill="both", expand=False)

frame3 = tk.Frame(window)
frame3.pack(side="bottom", fill="x", expand=False)
#快捷鍵===========================================================================


# example = tk.Button(frame1, command=example, text="example",
#                    background="#FFE873", foreground="#4B8BBE",
#                    activebackground="#FFD43B", activeforeground="#306998",
#                    width=32, height=32, image = example_gif,
#                    padx=0, pady=0)


open_gif = tk.PhotoImage(file='b.gif')
b_open = tk.Button(frame1, command=openfile, width=32, height=32, image=open_gif)
b_open.grid(column=0, row=0)

openphoto_gif = tk.PhotoImage(file='openphoto.gif')
b_openphoto = tk.Button(frame1, command=openphoto, width=32, height=32, image=openphoto_gif)
b_openphoto.grid(column=1, row=0)

save_gif = tk.PhotoImage(file='save.gif')
b_save = tk.Button(frame1, command=save, width=32, height=32, image=save_gif)
b_save.grid(column=2, row=0) 

saveas_gif = tk.PhotoImage(file='saveas.gif')
b_saveas = tk.Button(frame1, command=saveas, width=32, height=32, image=saveas_gif)
b_saveas.grid(column=3, row=0) 

calculation_gif = tk.PhotoImage(file='calculation.gif')
b_calculation = tk.Button(frame1, text="calculation", command=calculation, width=32, height=32, image=calculation_gif)
b_calculation.grid(column=4, row=0)
              
clear_gif = tk.PhotoImage(file='clear.gif')   
b_clear = tk.Button(frame1, command=clear, width=32, height=32, image=clear_gif)
b_clear.grid(column=5, row=0)   

clearphoto_gif = tk.PhotoImage(file='clearphoto.gif')
b_clear = tk.Button(frame1, command=clearphoto, width=32, height=32, image=clearphoto_gif)
b_clear.grid(column=6, row=0)   


about_gif = tk.PhotoImage(file='about.gif')
b_about = tk.Button(frame1, command=about, width=32, height=32, image=about_gif)
b_about.grid(column=7, row=0)
#主畫面=========================================================================

p1 = tk.PanedWindow(showhandle=False)
p1.pack(fill="both", expand=1)
left = tk.Canvas(p1)
p1.add(left)
p2 = tk.PanedWindow(orient="vertical", showhandle=False)
p1.add(p2)
top = tk.Canvas(p2)
p2.add(top)
bottom = tk.Canvas(p2)
p2.add(bottom)


sbar1 = tk.Scrollbar(left, orient="vertical")
text1 = tk.Text(left, wrap='word', background="white", foreground="black", font=("System",10))
text1.insert('end', 'Start\n')
sbar1.pack(side='right', fill='both',expand=False)
text1.pack(side='left', fill='both',expand=True)
sbar1["command"] = text1.yview
text1["yscrollcommand"] = sbar1.set

# sbar2 = tk.Scrollbar(top, orient='horizontal')
# text2 = tk.Text(top, wrap='none', background="#FFE873", foreground="#306998", font=('Comic Sans MS',10))
# text2.insert('end', 'Start\n')
# sbar2.pack(side='bottom', fill='both',expand=False)
# text2.pack(side='left', fill='both',expand=True)
# sbar2["command"] =text2.xview
# text2["xscrollcommand"] =sbar2.set

label = tk.Label(top, bg="#FFE873")
label.pack(side='top', fill='both',expand=True)

sbar3 = tk.Scrollbar(bottom)
text3 = tk.Text(bottom, wrap='word', background="#4B8BBE", foreground="#306998", font=("System",10))
text3.insert('end', 'Start\n')
sbar3.pack(side='right', fill='both',expand=False)
text3.pack(side='left', fill='both',expand=True)
sbar3["command"] = text3.yview
text3["yscrollcommand"] = sbar3.set

#底部資訊======================================================
l1 = tk.Label(frame3, text="c1")
l1.config(width=10, height=1)
l1.pack(side="right")

l2 = tk.Label(frame3, text="c2")
l2.config(width=10, height=1)
l2.pack(side="right")
              
l3 = tk.Label(frame3, text="c3")
l3.config(width=10, height=1)
l3.pack(side="right")

window.mainloop()

# %% [markdown]
# #### PIL改變像素大小

# %%
from PIL import Image

src = Image.open( "h.gif" )
print(src.size)
dst = src.resize((22, 22), Image.BILINEAR )
print(dst.size)

nim.save("about.gif")
# Out:
# (225, 225)
# (22, 22)
